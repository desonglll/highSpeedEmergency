# %%
# 导入必要的库
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# 设置Seaborn的主题
sns.set(style="whitegrid")

# %%
from tools.csv import csv_files

csv_list = csv_files("./res")
for csv_file in csv_list:
    print(csv_file.split('/')[-2].split('.')[-1])
# Out:
# 105
# 105
# 105
# 103
# 103
# 108
# 108
# 107
# 107
# 105
# 105
# 105
# 105
# 103
# 108
# 107
# 103
# 103
# 105
# 105
# 105
# 103
# 103
# 108
# 108
# 107
# 107
# 108
# 108
# 107
# 107

# %%
for csv_file in csv_list:
    # 检查CSV文件是否存在
    if not os.path.exists(csv_file):
        # 如果CSV文件不存在，创建一个示例文件
        sample_data = """Frame,Flow,Density
    25,4,19
    50,2,20
    75,2,18
    100,2,20
    125,3,20
    150,1,18
    175,1,12
    200,2,14
    225,2,12
    250,1,11
    275,3,14
    """
        with open(csv_file, 'w') as f:
            f.write(sample_data)
        print(f"已创建示例CSV文件: {csv_file}")

    # 从CSV文件中读取数据
    df = pd.read_csv(csv_file)

    # 查看数据基本信息
    print("数据预览：")
    print(df.head())

    # 检查缺失值
    print("\n缺失值检查：")
    print(df.isnull().sum())

    # 描述性统计
    print("\n描述性统计：")
    print(df.describe())

    # 创建一个保存图像的目录
    output_dir = './plots/q1_plots_single'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)

    # 1. 时间序列图
    plt.figure(figsize=(10, 6))
    plt.plot(df['Frame'], df['Flow'], marker='o', label='Flow', color='blue')
    plt.plot(df['Frame'], df['Density'], marker='s', label='Density', color='orange')
    plt.title('Traffic flow and density change with frame rate')
    plt.xlabel('Frame')
    plt.ylabel('Value')
    plt.legend()
    plt.tight_layout()
    # 保存图像
    time_series_path = os.path.join(output_dir,
                                    f'{csv_file.split("/")[-2].split(".")[-1] + "_" + csv_file.split("/")[-1].split(".")[0]}_time_series.png')
    plt.savefig(time_series_path)
    plt.close()
    print(f"时间序列图已保存为 {time_series_path}")

    # 2. 散点图
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='Flow', y='Density', data=df, s=100, color='b')
    plt.title('Scatter plot of the relationship between traffic flow and vehicle density')
    plt.xlabel('Flow')
    plt.ylabel('Density')
    plt.tight_layout()
    # 保存图像
    scatter_path = os.path.join(output_dir,
                                f'{csv_file.split("/")[-2].split(".")[-1] + "_" + csv_file.split("/")[-1].split(".")[0]}_scatter_plot.png')
    plt.savefig(scatter_path)
    plt.close()
    print(f"散点图已保存为 {scatter_path}")

    # 3. 相关性热图
    corr = df[['Flow', 'Density']].corr()
    plt.figure(figsize=(6, 4))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Heat map of the correlation between traffic flow and vehicle density')
    plt.tight_layout()
    # 保存图像
    heatmap_path = os.path.join(output_dir,
                                f'{csv_file.split("/")[-2].split(".")[-1] + "_" + csv_file.split("/")[-1].split(".")[0]}_correlation_heatmap.png')
    plt.savefig(heatmap_path)
    plt.close()
    print(f"相关性热图已保存为 {heatmap_path}")

    # 4. 直方图
    plt.figure(figsize=(12, 5))

    # 车流量直方图
    plt.subplot(1, 2, 1)
    sns.histplot(df['Flow'], bins=5, kde=True, color='g')
    plt.title('Flow')
    plt.xlabel('Flow')
    plt.ylabel('Frequency')

    # 车密度直方图
    plt.subplot(1, 2, 2)
    sns.histplot(df['Density'], bins=5, kde=True, color='r')
    plt.title('Density')
    plt.xlabel('Density')
    plt.ylabel('frequency')

    plt.tight_layout()
    # 保存图像
    histogram_path = os.path.join(output_dir,
                                  f'{csv_file.split("/")[-2].split(".")[-1] + "_" + csv_file.split("/")[-1].split(".")[0]}_histograms.png')
    plt.savefig(histogram_path)
    plt.close()
    print(f"直方图已保存为 {histogram_path}")
    i+=1
# Out:
# 数据预览：
#    Frame  Flow  Density
# 0     25     1        7
# 1     50     1       12
# 2     75     2        8
# 3    100     2        9
# 4    125     1        7
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    430.000000  430.000000  430.000000
# mean    5387.500000    0.932558    8.725581
# std     3106.864041    0.749583    2.713009
# min       25.000000    0.000000    2.000000
# 25%     2706.250000    0.000000    7.000000
# 50%     5387.500000    1.000000    9.000000
# 75%     8068.750000    1.000000   10.000000
# max    10750.000000    4.000000   16.000000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     0        9
# 1     50     1        6
# 2     75     1        9
# 3    100     0        7
# 4    125     0        2
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    430.000000  430.000000  430.000000
# mean    5387.500000    0.804651    6.660465
# std     3106.864041    1.003015    3.599543
# min       25.000000    0.000000    0.000000
# 25%     2706.250000    0.000000    4.000000
# 50%     5387.500000    0.500000    7.000000
# 75%     8068.750000    1.000000    9.000000
# max    10750.000000    5.000000   19.000000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     2        6
# 1     50     1        2
# 2     75     0        4
# 3    100     0        3
# 4    125     1        6
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    434.000000  434.000000  434.000000
# mean    5437.500000    0.211982    3.917051
# std     3135.731573    0.431169    2.069806
# min       25.000000    0.000000    0.000000
# 25%     2731.250000    0.000000    3.000000
# 50%     5437.500000    0.000000    4.000000
# 75%     8143.750000    0.000000    5.000000
# max    10850.000000    2.000000   11.000000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     4        7
# 1     50     3       11
# 2     75     1       10
# 3    100     1       10
# 4    125     1        4
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    431.000000  431.000000  431.000000
# mean    5400.000000    0.278422    4.120650
# std     3114.080924    0.507134    2.502894
# min       25.000000    0.000000    0.000000
# 25%     2712.500000    0.000000    2.000000
# 50%     5400.000000    0.000000    4.000000
# 75%     8087.500000    1.000000    5.000000
# max    10775.000000    4.000000   16.000000
# 时间序列图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     3       16
# 1     50     2       15
# 2     75     3       11
# 3    100     2       11
# 4    125     3       16
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    427.000000  427.000000  427.000000
# mean    5350.000000    1.932084   10.798595
# std     3085.213391    0.925678    2.927400
# min       25.000000    0.000000    2.000000
# 25%     2687.500000    1.000000    9.000000
# 50%     5350.000000    2.000000   11.000000
# 75%     8012.500000    2.000000   13.000000
# max    10675.000000    5.000000   20.000000
# 时间序列图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     4        7
# 1     50     5        7
# 2     75     7        9
# 3    100     6       11
# 4    125    10       12
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1092.000000  1092.000000  1092.000000
# mean   13662.500000     5.355311     7.663919
# std     7884.438788     2.041759     2.247650
# min       25.000000     0.000000     0.000000
# 25%     6843.750000     4.000000     6.000000
# 50%    13662.500000     5.000000     8.000000
# 75%    20481.250000     7.000000     9.000000
# max    27300.000000    12.000000    14.000000
# 时间序列图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     5        6
# 1     50     5        6
# 2     75     7       10
# 3    100     6        7
# 4    125     4        4
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1092.000000  1092.000000  1092.000000
# mean   13662.500000     2.662088     4.772894
# std     7884.438788     1.936269     2.297266
# min       25.000000     0.000000     0.000000
# 25%     6843.750000     1.000000     3.000000
# 50%    13662.500000     2.000000     5.000000
# 75%    20481.250000     4.000000     6.000000
# max    27300.000000    11.000000    14.000000
# 时间序列图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     0        4
# 1     50     0        6
# 2     75     0        5
# 3    100     0        0
# 4    125     0        2
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1093.000000  1093.000000  1093.000000
# mean   13675.000000     0.198536     4.492223
# std     7891.655667     0.448765     2.400241
# min       25.000000     0.000000     0.000000
# 25%     6850.000000     0.000000     3.000000
# 50%    13675.000000     0.000000     4.000000
# 75%    20500.000000     0.000000     6.000000
# max    27325.000000     2.000000    13.000000
# 时间序列图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     1        6
# 1     50     1       10
# 2     75     1        9
# 3    100     1       12
# 4    125     1        8
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1092.000000  1092.000000  1092.000000
# mean   13662.500000     0.610806     7.937729
# std     7884.438788     0.680750     2.484003
# min       25.000000     0.000000     0.000000
# 25%     6843.750000     0.000000     6.000000
# 50%    13662.500000     1.000000     8.000000
# 75%    20481.250000     1.000000    10.000000
# max    27300.000000     3.000000    17.000000
# 时间序列图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     1       14
# 1     50     1       11
# 2     75     1        7
# 3    100     1       11
# 4    125     1        8
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    430.000000  430.000000  430.000000
# mean    5387.500000    0.888372   13.274419
# std     3106.864041    0.683884    3.882187
# min       25.000000    0.000000    3.000000
# 25%     2706.250000    0.000000   11.000000
# 50%     5387.500000    1.000000   13.000000
# 75%     8068.750000    1.000000   16.000000
# max    10750.000000    3.000000   24.000000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     0        9
# 1     50     1       17
# 2     75     1       15
# 3    100     0        9
# 4    125     0       13
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    430.000000  430.000000  430.000000
# mean    5387.500000    0.713953   10.988372
# std     3106.864041    0.871481    5.120675
# min       25.000000    0.000000    0.000000
# 25%     2706.250000    0.000000    8.000000
# 50%     5387.500000    0.000000   11.000000
# 75%     8068.750000    1.000000   15.000000
# max    10750.000000    5.000000   27.000000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     1        7
# 1     50     0        0
# 2     75     0        8
# 3    100     1        5
# 4    125     1        8
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    434.000000  434.000000  434.000000
# mean    5437.500000    0.193548    6.799539
# std     3135.731573    0.401331    3.876131
# min       25.000000    0.000000    0.000000
# 25%     2731.250000    0.000000    4.000000
# 50%     5437.500000    0.000000    6.500000
# 75%     8143.750000    0.000000    9.000000
# max    10850.000000    2.000000   21.000000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     3        7  0.000000
# 1     50     8       12  0.000000
# 2     75     6        8  3.710444
# 3    100     8        9  0.559052
# 4    125     5        7  7.500463
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   1295.000000  1295.000000  1295.000000  1295.000000
# mean   16200.000000     4.756757     6.410811     2.491268
# std     9349.465225     3.295397     3.505290     2.749595
# min       25.000000     0.000000     0.000000     0.000000
# 25%     8112.500000     2.000000     4.000000     0.000000
# 50%    16200.000000     4.000000     6.000000     2.072952
# 75%    24287.500000     7.000000     9.000000     4.317288
# max    32375.000000    16.000000    18.000000    20.265136
# 时间序列图已保存为 ./plots/q1_plots_single/105_105_combined_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_105_combined_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_105_combined_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_105_combined_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     9       16  0.000000
# 1     50     8       15  5.304191
# 2     75     7       11  0.750000
# 3    100     7       11  8.101286
# 4    125     9       16  5.914863
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density       Speed
# count    859.000000  859.000000  859.000000  859.000000
# mean   10750.000000    3.548312    7.410943    3.306647
# std     6202.905905    3.048700    4.348450    3.894070
# min       25.000000    0.000000    0.000000    0.000000
# 25%     5387.500000    1.000000    4.000000    0.000000
# 50%    10750.000000    3.000000    7.000000    2.417708
# 75%    16112.500000    6.000000   11.000000    5.493125
# max    21475.000000   12.000000   20.000000   26.145028
# 时间序列图已保存为 ./plots/q1_plots_single/103_103_combined_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_103_combined_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_103_combined_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_103_combined_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     7        7  0.000000
# 1     50     7        7  2.673311
# 2     75     9        9  4.891245
# 3    100    11       11  8.219152
# 4    125    12       12  8.222164
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   2185.000000  2185.000000  2185.000000  2185.000000
# mean   27325.000000     6.236613     6.244394     4.309690
# std    15772.487254     2.695019     2.701876     6.046206
# min       25.000000     0.000000     0.000000     0.000000
# 25%    13675.000000     4.000000     4.000000     0.000000
# 50%    27325.000000     6.000000     6.000000     2.970109
# 75%    40975.000000     8.000000     8.000000     6.313929
# max    54625.000000    14.000000    14.000000    92.751596
# 时间序列图已保存为 ./plots/q1_plots_single/108_108_combined_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_108_combined_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_108_combined_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_108_combined_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     6        6  0.000000
# 1     50    10       10  6.551767
# 2     75     9        9  2.619944
# 3    100    12       12  9.142456
# 4    125     8        8  6.813729
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   2185.000000  2185.000000  2185.000000  2185.000000
# mean   27325.000000     5.781693     6.204119     3.563387
# std    15772.487254     2.976008     3.005106     4.670359
# min       25.000000     0.000000     0.000000     0.000000
# 25%    13675.000000     3.000000     4.000000     0.000000
# 50%    27325.000000     6.000000     6.000000     2.531467
# 75%    40975.000000     8.000000     8.000000     5.551012
# max    54625.000000    15.000000    17.000000    52.141908
# 时间序列图已保存为 ./plots/q1_plots_single/107_107_combined_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_107_combined_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_107_combined_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_107_combined_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     3       15
# 1     50     3       16
# 2     75     1       13
# 3    100     1       15
# 4    125     1       16
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    431.000000  431.000000  431.000000
# mean    5400.000000    0.285383    7.522042
# std     3114.080924    0.505546    4.100919
# min       25.000000    0.000000    0.000000
# 25%     2712.500000    0.000000    5.000000
# 50%     5400.000000    0.000000    7.000000
# 75%     8087.500000    1.000000   10.000000
# max    10775.000000    3.000000   21.000000
# 时间序列图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     4       19
# 1     50     2       20
# 2     75     2       18
# 3    100     2       20
# 4    125     3       20
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density
# count    427.000000  427.000000  427.000000
# mean    5350.000000    1.873536   16.360656
# std     3085.213391    0.887010    3.522716
# min       25.000000    0.000000    5.000000
# 25%     2687.500000    1.000000   14.000000
# 50%     5350.000000    2.000000   17.000000
# 75%     8012.500000    2.000000   19.000000
# max    10675.000000    4.000000   26.000000
# 时间序列图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     3        7  0.000000
# 1     50     8       12  0.000000
# 2     75     6        8  3.710215
# 3    100     8        9  0.559017
# 4    125     5        7  7.500000
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density       Speed
# count    430.000000  430.000000  430.000000  430.000000
# mean    5387.500000    6.972093    8.725581    3.591948
# std     3106.864041    2.771679    2.713009    2.587058
# min       25.000000    0.000000    2.000000    0.000000
# 25%     2706.250000    5.000000    7.000000    1.753757
# 50%     5387.500000    7.000000    9.000000    3.651518
# 75%     8068.750000    9.000000   10.000000    5.078416
# max    10750.000000   15.000000   16.000000   16.757562
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     5        9  0.000000
# 1     50     4        6  6.324555
# 2     75     6        9  2.712790
# 3    100     3        7  2.249957
# 4    125     2        2  0.000000
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density       Speed
# count    430.000000  430.000000  430.000000  430.000000
# mean    5387.500000    4.825581    6.660465    2.818591
# std     3106.864041    3.375463    3.599543    4.636309
# min       25.000000    0.000000    0.000000    0.000000
# 25%     2706.250000    2.000000    4.000000    0.000000
# 50%     5387.500000    4.000000    7.000000    1.707149
# 75%     8068.750000    7.000000    9.000000    4.428920
# max    10750.000000   16.000000   19.000000   71.250000
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501130415_20240501141554_130415_histograms.png
# 数据预览：
#    Frame  Flow  Density  Speed
# 0     25     4        6    0.0
# 1     50     1        2    0.0
# 2     75     4        4    0.0
# 3    100     2        3    0.0
# 4    125     4        6    0.0
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density       Speed
# count    434.000000  434.000000  434.000000  434.000000
# mean    5437.500000    2.433180    3.917051    1.230185
# std     3135.731573    1.745044    2.069806    2.093740
# min       25.000000    0.000000    0.000000    0.000000
# 25%     2731.250000    1.000000    3.000000    0.000000
# 50%     5437.500000    2.000000    4.000000    0.000000
# 75%     8143.750000    3.000000    5.000000    2.146936
# max    10850.000000    8.000000   11.000000   13.009612
# 时间序列图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/105_20240501_20240501141554_20240501152820_141555_histograms.png
# 数据预览：
#    Frame  Flow  Density      Speed
# 0     25     4        7   0.000000
# 1     50     9       11   0.000000
# 2     75     6       10  10.006248
# 3    100     4       10   4.197400
# 4    125     1        4   3.097726
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density       Speed
# count    431.000000  431.000000  431.000000  431.000000
# mean    5400.000000    1.083527    4.120650    1.098604
# std     3114.080924    1.243582    2.502894    2.042141
# min       25.000000    0.000000    0.000000    0.000000
# 25%     2712.500000    0.000000    2.000000    0.000000
# 50%     5400.000000    1.000000    4.000000    0.000000
# 75%     8087.500000    2.000000    5.000000    1.590960
# max    10775.000000    9.000000   16.000000   15.502016
# 时间序列图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_20240501_20240501140806_20240501152004_140807_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     9       16  0.000000
# 1     50     8       15  5.304191
# 2     75     7       11  0.750000
# 3    100     7       11  8.101286
# 4    125     9       16  5.914863
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame        Flow     Density       Speed
# count    427.000000  427.000000  427.000000  427.000000
# mean    5350.000000    6.051522   10.798595    5.462909
# std     3085.213391    2.145454    2.927400    4.011433
# min       25.000000    1.000000    2.000000    0.000000
# 25%     2687.500000    5.000000    9.000000    3.178979
# 50%     5350.000000    6.000000   11.000000    4.977923
# 75%     8012.500000    7.000000   13.000000    7.126598
# max    10675.000000   12.000000   20.000000   26.145028
# 时间序列图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     7        7  0.000000
# 1     50     7        7  2.673213
# 2     75     9        9  4.891066
# 3    100    11       11  8.218851
# 4    125    12       12  8.221863
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   1092.000000  1092.000000  1092.000000  1092.000000
# mean   13662.500000     7.651099     7.663919     6.156905
# std     7884.438788     2.240791     2.247650     7.073260
# min       25.000000     0.000000     0.000000     0.000000
# 25%     6843.750000     6.000000     6.000000     1.980000
# 50%    13662.500000     8.000000     8.000000     4.993806
# 75%    20481.250000     9.000000     9.000000     8.186153
# max    27300.000000    14.000000    14.000000    92.748201
# 时间序列图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_histograms.png
# 数据预览：
#    Frame  Flow  Density      Speed
# 0     25     6        6   0.000000
# 1     50     6        6   1.650000
# 2     75    10       10   2.213707
# 3    100     7        7   6.866855
# 4    125     4        4  46.394482
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   1092.000000  1092.000000  1092.000000  1092.000000
# mean   13662.500000     4.771062     4.772894     2.573513
# std     7884.438788     2.295487     2.297266     5.188408
# min       25.000000     0.000000     0.000000     0.000000
# 25%     6843.750000     3.000000     3.000000     0.000000
# 50%    13662.500000     5.000000     5.000000     0.000000
# 75%    20481.250000     6.000000     6.000000     3.689512
# max    27300.000000    14.000000    14.000000    59.554715
# 时间序列图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     2        4  0.000000
# 1     50     4        6  4.028163
# 2     75     5        5  5.949160
# 3    100     0        0  0.000000
# 4    125     2        2  0.000000
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   1093.000000  1093.000000  1093.000000  1093.000000
# mean   13675.000000     4.158280     4.492223     2.142154
# std     7891.655667     2.324345     2.400241     3.472452
# min       25.000000     0.000000     0.000000     0.000000
# 25%     6850.000000     2.000000     3.000000     0.000000
# 50%    13675.000000     4.000000     4.000000     0.000000
# 75%    20500.000000     6.000000     6.000000     3.630000
# max    27325.000000    13.000000    13.000000    26.019825
# 时间序列图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_histograms.png
# 数据预览：
#    Frame  Flow  Density     Speed
# 0     25     6        6  0.000000
# 1     50    10       10  6.551528
# 2     75     9        9  2.619848
# 3    100    12       12  9.142122
# 4    125     8        8  6.813479
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# Speed      0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density        Speed
# count   1092.000000  1092.000000  1092.000000  1092.000000
# mean   13662.500000     7.431319     7.937729     4.977533
# std     7884.438788     2.606811     2.484003     5.008392
# min       25.000000     0.000000     0.000000     0.000000
# 25%     6843.750000     6.000000     6.000000     1.360625
# 50%    13662.500000     8.000000     8.000000     4.136544
# 75%    20481.250000     9.000000    10.000000     6.879430
# max    27300.000000    15.000000    17.000000    48.840000
# 时间序列图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     4        9
# 1     50     5       11
# 2     75     8       10
# 3    100     4        7
# 4    125     7       10
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1092.000000  1092.000000  1092.000000
# mean   13662.500000     4.673993     8.867216
# std     7884.438788     1.689983     2.738821
# min       25.000000     0.000000     1.000000
# 25%     6843.750000     4.000000     7.000000
# 50%    13662.500000     5.000000     9.000000
# 75%    20481.250000     6.000000    11.000000
# max    27300.000000     9.000000    17.000000
# 时间序列图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     4        7
# 1     50     5        6
# 2     75     7       10
# 3    100     5        6
# 4    125     4        4
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1092.000000  1092.000000  1092.000000
# mean   13662.500000     2.286630     7.085165
# std     7884.438788     1.606952     2.969919
# min       25.000000     0.000000     0.000000
# 25%     6843.750000     1.000000     5.000000
# 50%    13662.500000     2.000000     7.000000
# 75%    20481.250000     3.000000     9.000000
# max    27300.000000     8.000000    17.000000
# 时间序列图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/108_20240501_20240501135236_20240501160912_135235_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     0        4
# 1     50     0        6
# 2     75     0        5
# 3    100     0        0
# 4    125     0        2
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1093.000000  1093.000000  1093.000000
# mean   13675.000000     0.175663     4.561757
# std     7891.655667     0.385488     2.212411
# min       25.000000     0.000000     0.000000
# 25%     6850.000000     0.000000     3.000000
# 50%    13675.000000     0.000000     4.000000
# 75%    20500.000000     0.000000     6.000000
# max    27325.000000     2.000000    12.000000
# 时间序列图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_20240501_20240501135755_20240501161432_135755_histograms.png
# 数据预览：
#    Frame  Flow  Density
# 0     25     1        6
# 1     50     1       11
# 2     75     1        9
# 3    100     1       10
# 4    125     1       10
#
# 缺失值检查：
# Frame      0
# Flow       0
# Density    0
# dtype: int64
#
# 描述性统计：
#               Frame         Flow      Density
# count   1092.000000  1092.000000  1092.000000
# mean   13662.500000     0.518315     7.682234
# std     7884.438788     0.563668     2.179552
# min       25.000000     0.000000     0.000000
# 25%     6843.750000     0.000000     6.000000
# 50%    13662.500000     0.000000     8.000000
# 75%    20481.250000     1.000000     9.000000
# max    27300.000000     3.000000    13.000000
# 时间序列图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_time_series.png
# 散点图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_scatter_plot.png
# 相关性热图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_correlation_heatmap.png
# 直方图已保存为 ./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_histograms.png
