# %%
import pandas as pd
import matplotlib.pyplot as plt


# Function to read CSV, remove rows where Speed is 0, and plot trends over time (minutes)
def plot_trends_by_time(csv_path, plot_title):
    # Read CSV data
    data = pd.read_csv(csv_path)

    # Remove rows where Speed is 0
    data = data[data['Speed'] > 0]

    # Convert Frame to Time in minutes (1 minute = 200 frames)
    data['Time (minutes)'] = data['Frame'] / 225.0

    # Create subplots for Flow, Density, and Speed vs Time (minutes)
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    # Set the title for the entire figure
    fig.suptitle(plot_title, fontsize=16)
    # Plot Flow vs Time
    axs[0].plot(data['Time (minutes)'], data['Flow'], color='b', label='Flow')
    axs[0].set_title('Flow vs Time (minutes)')
    axs[0].set_xlabel('Time (minutes)')
    axs[0].set_ylabel('Flow')
    axs[0].grid(True)

    # Plot Density vs Time
    axs[1].plot(data['Time (minutes)'], data['Density'], color='g', label='Density')
    axs[1].set_title('Density vs Time (minutes)')
    axs[1].set_xlabel('Time (minutes)')
    axs[1].set_ylabel('Density')
    axs[1].grid(True)

    # Plot Speed vs Time
    axs[2].plot(data['Time (minutes)'], data['Speed'], color='r', label='Speed')
    axs[2].set_title('Speed vs Time (minutes)')
    axs[2].set_xlabel('Time (minutes)')
    axs[2].set_ylabel('Speed')
    axs[2].grid(True)

    # Adjust layout
    plt.tight_layout()

    # Show plots
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Function to read CSV, remove rows where Speed is 0, and plot trends over time (minutes)
def plot_trends_by_time_105(csv_path, plot_title):
    # Read CSV data
    data = pd.read_csv(csv_path)

    # Remove rows where Speed is 0
    data = data[data['Speed'] > 0]

    # Convert Frame to Time in minutes (1 minute = 200 frames)
    data['Time (minutes)'] = data['Frame'] / 160.0

    # Create subplots for Flow, Density, and Speed vs Time (minutes)
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    # Set the title for the entire figure
    fig.suptitle(plot_title, fontsize=16)
    # Plot Flow vs Time
    axs[0].plot(data['Time (minutes)'], data['Flow'], color='b', label='Flow')
    axs[0].set_title('Flow vs Time (minutes)')
    axs[0].set_xlabel('Time (minutes)')
    axs[0].set_ylabel('Flow')
    axs[0].grid(True)

    # Plot Density vs Time
    axs[1].plot(data['Time (minutes)'], data['Density'], color='g', label='Density')
    axs[1].set_title('Density vs Time (minutes)')
    axs[1].set_xlabel('Time (minutes)')
    axs[1].set_ylabel('Density')
    axs[1].grid(True)

    # Plot Speed vs Time
    axs[2].plot(data['Time (minutes)'], data['Speed'], color='r', label='Speed')
    axs[2].set_title('Speed vs Time (minutes)')
    axs[2].set_xlabel('Time (minutes)')
    axs[2].set_ylabel('Speed')
    axs[2].grid(True)

    # Adjust layout
    plt.tight_layout()

    # Show plots
    plt.show()

# %%
plot_trends_by_time_105("./res/with-speed-combined/32.31.250.105/105_combined.csv", "Monitoring Point 2 (32.31.250.105)")

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Function to read CSV, remove rows where Speed is 0, and plot trends over time (minutes)
def plot_trends_by_time_103(csv_path, plot_title):
    # Read CSV data
    data = pd.read_csv(csv_path)

    # Remove rows where Speed is 0
    data = data[data['Speed'] > 0]

    # Convert Frame to Time in minutes (1 minute = 200 frames)
    data['Time (minutes)'] = data['Frame'] / 150.0

    # Create subplots for Flow, Density, and Speed vs Time (minutes)
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    # Set the title for the entire figure
    fig.suptitle(plot_title, fontsize=16)
    # Plot Flow vs Time
    axs[0].plot(data['Time (minutes)'], data['Flow'], color='b', label='Flow')
    axs[0].set_title('Flow vs Time (minutes)')
    axs[0].set_xlabel('Time (minutes)')
    axs[0].set_ylabel('Flow')
    axs[0].grid(True)

    # Plot Density vs Time
    axs[1].plot(data['Time (minutes)'], data['Density'], color='g', label='Density')
    axs[1].set_title('Density vs Time (minutes)')
    axs[1].set_xlabel('Time (minutes)')
    axs[1].set_ylabel('Density')
    axs[1].grid(True)

    # Plot Speed vs Time
    axs[2].plot(data['Time (minutes)'], data['Speed'], color='r', label='Speed')
    axs[2].set_title('Speed vs Time (minutes)')
    axs[2].set_xlabel('Time (minutes)')
    axs[2].set_ylabel('Speed')
    axs[2].grid(True)

    # Adjust layout
    plt.tight_layout()

    # Show plots
    plt.show()

# %%
plot_trends_by_time_103("./res/with-speed-combined/32.31.250.103/103_combined.csv",
                        "Monitoring Point 4 (32.31.250.103)")

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Function to read CSV, remove rows where Speed is 0, and plot trends over time (minutes)
def plot_trends_by_time_108(csv_path, plot_title):
    # Read CSV data
    data = pd.read_csv(csv_path)

    # Remove rows where Speed is 0
    data = data[data['Speed'] > 0]

    # Convert Frame to Time in minutes (1 minute = 200 frames)
    data['Time (minutes)'] = data['Frame'] / 200.0

    # Create subplots for Flow, Density, and Speed vs Time (minutes)
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    # Set the title for the entire figure
    fig.suptitle(plot_title, fontsize=16)
    # Plot Flow vs Time
    axs[0].plot(data['Time (minutes)'], data['Flow'], color='b', label='Flow')
    axs[0].set_title('Flow vs Time (minutes)')
    axs[0].set_xlabel('Time (minutes)')
    axs[0].set_ylabel('Flow')
    axs[0].grid(True)

    # Plot Density vs Time
    axs[1].plot(data['Time (minutes)'], data['Density'], color='g', label='Density')
    axs[1].set_title('Density vs Time (minutes)')
    axs[1].set_xlabel('Time (minutes)')
    axs[1].set_ylabel('Density')
    axs[1].grid(True)

    # Plot Speed vs Time
    axs[2].plot(data['Time (minutes)'], data['Speed'], color='r', label='Speed')
    axs[2].set_title('Speed vs Time (minutes)')
    axs[2].set_xlabel('Time (minutes)')
    axs[2].set_ylabel('Speed')
    axs[2].grid(True)

    # Adjust layout
    plt.tight_layout()

    # Show plots
    plt.show()

# %%
plot_trends_by_time_108("./res/with-speed-combined/32.31.250.108/108_combined.csv",
                        "Monitoring Point 3 (32.31.250.108)")
# 270min

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Function to read CSV, remove rows where Speed is 0, and plot trends over time (minutes)
def plot_trends_by_time_107(csv_path, plot_title):
    # Read CSV data
    data = pd.read_csv(csv_path)

    # Remove rows where Speed is 0
    data = data[data['Speed'] > 0]

    # Convert Frame to Time in minutes (1 minute = 200 frames)
    data['Time (minutes)'] = data['Frame'] / 200.0

    # Create subplots for Flow, Density, and Speed vs Time (minutes)
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    # Set the title for the entire figure
    fig.suptitle(plot_title, fontsize=16)
    # Plot Flow vs Time
    axs[0].plot(data['Time (minutes)'], data['Flow'], color='b', label='Flow')
    axs[0].set_title('Flow vs Time (minutes)')
    axs[0].set_xlabel('Time (minutes)')
    axs[0].set_ylabel('Flow')
    axs[0].grid(True)

    # Plot Density vs Time
    axs[1].plot(data['Time (minutes)'], data['Density'], color='g', label='Density')
    axs[1].set_title('Density vs Time (minutes)')
    axs[1].set_xlabel('Time (minutes)')
    axs[1].set_ylabel('Density')
    axs[1].grid(True)

    # Plot Speed vs Time
    axs[2].plot(data['Time (minutes)'], data['Speed'], color='r', label='Speed')
    axs[2].set_title('Speed vs Time (minutes)')
    axs[2].set_xlabel('Time (minutes)')
    axs[2].set_ylabel('Speed')
    axs[2].grid(True)

    # Adjust layout
    plt.tight_layout()

    # Show plots
    plt.show()

# %%
plot_trends_by_time_107("./res/with-speed-combined/32.31.250.107/107_combined.csv", "Monitoring Point 1 (32.31.250.107)")
