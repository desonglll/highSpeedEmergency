# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


def combine_images_with_pyplot(img1_path, img2_path, orientation='horizontal'):
    # 读取图片
    img1 = mpimg.imread(img1_path)
    img2 = mpimg.imread(img2_path)

    # 创建图形和子图
    if orientation == 'horizontal':
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))  # 1行2列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Monitoring Point 4 (32.31.250.103) Video 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Monitoring Point 4 (32.31.250.103) Video 2')

    elif orientation == 'vertical':
        fig, ax = plt.subplots(2, 1, figsize=(6, 12))  # 2行1列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Image 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Image 2')

    # 调整子图间距
    plt.tight_layout()

    # 显示合并后的图片
    plt.show()

# %%
combine_images_with_pyplot(
    "../plots/q1_model/32.31.250.103/20240501_20240501125647_20240501140806_125649_estimated_speed_plot.png",
    "../plots/q1_model/32.31.250.103/20240501_20240501140806_20240501152004_140807_estimated_speed_plot.png",
    orientation='horizontal')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


def combine_images_with_pyplot(img1_path, img2_path, orientation='horizontal'):
    # 读取图片
    img1 = mpimg.imread(img1_path)
    img2 = mpimg.imread(img2_path)

    # 创建图形和子图
    if orientation == 'horizontal':
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))  # 1行2列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Monitoring Point 1 (32.31.250.107) Video 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Monitoring Point 1 (32.31.250.107) Video 2')

    elif orientation == 'vertical':
        fig, ax = plt.subplots(2, 1, figsize=(6, 12))  # 2行1列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Image 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Image 2')

    # 调整子图间距
    plt.tight_layout()

    # 显示合并后的图片
    plt.show()

# %%
combine_images_with_pyplot(
    "../plots/q1_model/32.31.250.107/20240501_20240501114103_20240501135755_114103_estimated_speed_plot.png",
    "../plots/q1_model/32.31.250.107/20240501_20240501135755_20240501161432_135755_estimated_speed_plot.png",
    orientation='horizontal')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


def combine_images_with_pyplot(img1_path, img2_path, orientation='horizontal'):
    # 读取图片
    img1 = mpimg.imread(img1_path)
    img2 = mpimg.imread(img2_path)

    # 创建图形和子图
    if orientation == 'horizontal':
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))  # 1行2列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Monitoring Point 3 (32.31.250.108) Video 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Monitoring Point 3 (32.31.250.108) Video 2')

    elif orientation == 'vertical':
        fig, ax = plt.subplots(2, 1, figsize=(6, 12))  # 2行1列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Image 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Image 2')

    # 调整子图间距
    plt.tight_layout()

    # 显示合并后的图片
    plt.show()

# %%
combine_images_with_pyplot(
    "../plots/q1_model/32.31.250.108/20240501_20240501113543_20240501135236_113542_estimated_speed_plot.png",
    "../plots/q1_model/32.31.250.108/20240501_20240501135236_20240501160912_135235_estimated_speed_plot.png",
    orientation='horizontal')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


def combine_images_with_pyplot_loss(img1_path, img2_path, orientation='horizontal'):
    # 读取图片
    img1 = mpimg.imread(img1_path)
    img2 = mpimg.imread(img2_path)

    # 创建图形和子图
    if orientation == 'horizontal':
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))  # 1行2列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Flow')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Density')

    elif orientation == 'vertical':
        fig, ax = plt.subplots(2, 1, figsize=(6, 12))  # 2行1列
        ax[0].imshow(img1)
        ax[0].axis('off')  # 不显示坐标轴
        ax[0].set_title('Image 1')

        ax[1].imshow(img2)
        ax[1].axis('off')  # 不显示坐标轴
        ax[1].set_title('Image 2')

    # 调整子图间距
    plt.tight_layout()

    # 显示合并后的图片
    plt.show()

# %%
combine_images_with_pyplot_loss(
    "../plots/q1_lstm/32.31.250.103/20240501_20240501125647_20240501140806_125649.csv_Flow_loss_plot.png",
    "../plots/q1_lstm/32.31.250.103/20240501_20240501125647_20240501140806_125649.csv_Density_loss_plot.png",
    orientation='horizontal')
