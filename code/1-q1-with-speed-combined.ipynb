# %% [markdown]
# 应该是1，从视频提取出csv并保存

# %%
# 包含车速信息，代码运行很慢，因为有车速信息，所以必须要逐帧处理

import cv2
import numpy as np
import time
import pandas as pd
import os
import torch
from tqdm import tqdm

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.to('cpu')
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
# 定义检测的类（只检测车辆相关的类别）
classes_to_detect = ['bicycle', 'car', 'motorbike', 'bus', 'truck']

# %%
from tools.video import get_video_paths

video_paths = get_video_paths("./dataset/train_combined")

print(video_paths)
# Out:
# ['./dataset/train_combined/32.31.250.105/105_combined.mp4', './dataset/train_combined/32.31.250.103/103_combined.mp4', './dataset/train_combined/32.31.250.108/108_combined.mp4', './dataset/train_combined/32.31.250.107/107_combined.mp4']

# %%
for path in video_paths:
    file_folder = path.split('/')[-2]
    full_file_folder = str('/').join(path.split('/')[:-1])
    print(file_folder)
# Out:
# 32.31.250.105
# 32.31.250.103
# 32.31.250.108
# 32.31.250.107

# %%
def compute_iou(boxA, boxB):
    # boxA 和 boxB 是 [x1, y1, x2, y2] 格式
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # 计算交集面积
    interArea = max(0, xB - xA) * max(0, yB - yA)

    # 计算各自的面积
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])

    # 计算并集面积
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
# 逐帧处理视频
for path in tqdm(video_paths):
    file_folder = path.split('/')[-2]
    full_file_folder = str('/').join(path.split('/')[:-1])

    # 打开视频文件
    filename = os.path.basename(path)
    video_name = os.path.splitext(filename)[0]
    cap = cv2.VideoCapture(path)
    fps = cap.get(cv2.CAP_PROP_FPS)  # 获取视频帧率

    # 获取视频的帧数
    all_frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"视频总帧数: {all_frame_count}")

    # 定义流量线的位置
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    line_position = frame_height // 2  # 根据需要调整位置

    # 初始化变量
    frame_count = 0
    output_data = []
    vehicle_id_counter = 0  # 用于分配新的车辆ID
    vehicles = {}  # 存储车辆信息

    # 定义处理间隔（每25帧处理一次）
    process_frame_interval = 25  # 每25帧处理一次
    output_frame_interval = 25  # 每隔25帧输出一次

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame_count += 1

        # 仅每隔指定的帧数处理一次
        if frame_count % process_frame_interval != 0:
            continue

        # 使用 YOLOv8 进行推理
        results = model.predict(frame)  # YOLOv8的推理方法
        detections = results[0].boxes  # 获取第一个结果的检测框

        boxes = []
        confidences = []
        class_ids = []

        for box in detections:
            confidence = box.conf.item()  # 获取置信度
            class_id = int(box.cls.item())  # 获取类别ID
            if confidence > 0.3:  # 使用置信度阈值
                class_name = model.names[class_id]  # 获取类别名称
                if class_name in classes_to_detect:
                    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())  # 获取边界框坐标
                    boxes.append([x1, y1, x2, y2])  # 保持原始的坐标形式
                    confidences.append(confidence)
                    class_ids.append(class_id)

        # 车辆跟踪和速度计算
        current_vehicles = {}
        for box in boxes:
            x1, y1, x2, y2 = box
            matched = False
            for vehicle_id, vehicle_data in vehicles.items():
                prev_box = vehicle_data['box']
                iou = compute_iou([x1, y1, x2, y2], prev_box)
                if iou > 0.5:
                    dx = x1 - prev_box[0]
                    dy = y1 - prev_box[1]
                    distance = np.sqrt(dx * dx + dy * dy)
                    # speed = distance * fps  # 像素/秒
                    speed = (distance * 0.01) * fps  # 转换为米/秒

                    current_vehicles[vehicle_id] = {
                        'box': [x1, y1, x2, y2],
                        'speed': speed,
                        'frames': vehicle_data['frames'] + 1
                    }
                    matched = True
                    break
            if not matched:
                vehicle_id_counter += 1
                current_vehicles[vehicle_id_counter] = {
                    'box': [x1, y1, x2, y2],
                    'speed': 0,
                    'frames': 1
                }
        vehicles = current_vehicles

        # 计算密度和流量
        density = len(boxes)
        flow = sum(1 for box in boxes if box[1] <= line_position <= box[1] + box[3])

        speeds = [vehicle['speed'] for vehicle in vehicles.values() if vehicle['speed'] > 0]
        average_speed = sum(speeds) / len(speeds) if speeds else 0

        # 每隔一定帧数输出数据
        if frame_count % output_frame_interval == 0:
            output = {
                'Frame': frame_count,
                'Flow': flow,
                'Density': density,
                'Speed': average_speed
            }
            print(output)
            output_data.append(output)

    cap.release()

    # 保存结果到文件
    df = pd.DataFrame(output_data)
    saved_folder = f"./res/with-speed-combined/{file_folder}"
    if not os.path.exists(saved_folder):
        os.makedirs(saved_folder, exist_ok=True)
    df.to_csv(f'{saved_folder}/{video_name}.csv', index=False)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 视频总帧数: 32385
# 0: 384x640 4 cars, 2 buss, 1 truck, 1 traffic light, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 25, 'Flow': 3, 'Density': 7, 'Speed': 0}
# 0: 384x640 11 cars, 1 truck, 1 traffic light, 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 50, 'Flow': 8, 'Density': 12, 'Speed': 0}
# 0: 384x640 6 cars, 2 trucks, 1 traffic light, 51.2ms
# Speed: 2.1ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 75, 'Flow': 6, 'Density': 8, 'Speed': 3.710444369299247}
# 0: 384x640 7 cars, 2 trucks, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 100, 'Flow': 8, 'Density': 9, 'Speed': 0.5590515197119684}
# 0: 384x640 5 cars, 2 trucks, 1 traffic light, 51.7ms
# Speed: 1.6ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 125, 'Flow': 5, 'Density': 7, 'Speed': 7.5004632060031495}
# 0: 384x640 6 cars, 5 trucks, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 150, 'Flow': 6, 'Density': 10, 'Speed': 7.790139438503925}
# 0: 384x640 7 cars, 4 trucks, 53.6ms
# Speed: 2.1ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 175, 'Flow': 5, 'Density': 8, 'Speed': 5.250324244202204}
# 0: 384x640 8 cars, 2 buss, 2 trucks, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 200, 'Flow': 8, 'Density': 10, 'Speed': 4.776538278244515}
# 0: 384x640 10 cars, 1 bus, 1 truck, 54.9ms
# Speed: 2.2ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 225, 'Flow': 9, 'Density': 11, 'Speed': 13.220206021689611}
# 0: 384x640 12 cars, 1 bus, 1 traffic light, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 250, 'Flow': 9, 'Density': 13, 'Speed': 3.9430342356991233}
# 0: 384x640 11 cars, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 275, 'Flow': 11, 'Density': 11, 'Speed': 3.4192024889211416}
# 0: 384x640 10 cars, 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 300, 'Flow': 9, 'Density': 9, 'Speed': 4.336683419728438}
# 0: 384x640 15 cars, 48.9ms
# Speed: 1.6ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 325, 'Flow': 12, 'Density': 13, 'Speed': 6.1318440881234}
# 0: 384x640 13 cars, 52.6ms
# Speed: 2.1ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 350, 'Flow': 12, 'Density': 13, 'Speed': 5.141076577226587}
# 0: 384x640 11 cars, 2 trucks, 1 traffic light, 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 375, 'Flow': 10, 'Density': 11, 'Speed': 5.35515296367142}
# 0: 384x640 13 cars, 1 truck, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 400, 'Flow': 13, 'Density': 14, 'Speed': 4.857302127841606}
# 0: 384x640 9 cars, 1 truck, 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 425, 'Flow': 8, 'Density': 9, 'Speed': 4.981782288187858}
# 0: 384x640 7 cars, 2 trucks, 1 traffic light, 52.7ms
# Speed: 1.4ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 450, 'Flow': 7, 'Density': 9, 'Speed': 0}
# 0: 384x640 10 cars, 3 trucks, 49.2ms
# Speed: 1.4ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 475, 'Flow': 9, 'Density': 12, 'Speed': 8.832417883495811}
# 0: 384x640 12 cars, 3 trucks, 1 traffic light, 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 500, 'Flow': 11, 'Density': 13, 'Speed': 5.642611780564978}
# 0: 384x640 16 cars, 2 trucks, 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 525, 'Flow': 14, 'Density': 16, 'Speed': 4.140668458653776}
# 0: 384x640 14 cars, 1 truck, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 550, 'Flow': 11, 'Density': 13, 'Speed': 3.384334504395749}
# 0: 384x640 7 cars, 2 trucks, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 575, 'Flow': 9, 'Density': 9, 'Speed': 4.177335043002569}
# 0: 384x640 7 cars, 2 trucks, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 600, 'Flow': 8, 'Density': 8, 'Speed': 11.441000769363317}
# 0: 384x640 9 cars, 1 truck, 52.4ms
# Speed: 1.9ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 625, 'Flow': 8, 'Density': 8, 'Speed': 5.9336880077709555}
# 0: 384x640 12 cars, 1 truck, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 650, 'Flow': 10, 'Density': 10, 'Speed': 7.21813536155239}
# 0: 384x640 11 cars, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 675, 'Flow': 9, 'Density': 10, 'Speed': 6.318912246642837}
# 0: 384x640 14 cars, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 700, 'Flow': 13, 'Density': 14, 'Speed': 4.682967339577142}
# 0: 384x640 9 cars, 53.5ms
# Speed: 1.3ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 725, 'Flow': 8, 'Density': 9, 'Speed': 4.628769824400081}
# 0: 384x640 6 cars, 1 bus, 1 truck, 51.8ms
# Speed: 2.2ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 750, 'Flow': 8, 'Density': 8, 'Speed': 5.11393007353791}
# 0: 384x640 1 person, 9 cars, 1 traffic light, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 775, 'Flow': 8, 'Density': 8, 'Speed': 5.9328871430221}
# 0: 384x640 4 cars, 1 train, 1 traffic light, 53.7ms
# Speed: 2.5ms preprocess, 53.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 800, 'Flow': 3, 'Density': 4, 'Speed': 0.5590515197119684}
# 0: 384x640 7 cars, 2 buss, 56.5ms
# Speed: 1.7ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 825, 'Flow': 6, 'Density': 8, 'Speed': 0}
# 0: 384x640 12 cars, 1 bus, 2 trucks, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 850, 'Flow': 10, 'Density': 14, 'Speed': 10.701128148940398}
# 0: 384x640 11 cars, 52.2ms
# Speed: 1.5ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 875, 'Flow': 9, 'Density': 10, 'Speed': 5.293139342502311}
# 0: 384x640 14 cars, 50.9ms
# Speed: 1.7ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 900, 'Flow': 8, 'Density': 11, 'Speed': 1.7049592029103218}
# 0: 384x640 8 cars, 1 bus, 1 truck, 1 traffic light, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 925, 'Flow': 8, 'Density': 9, 'Speed': 5.384905609952242}
# 0: 384x640 9 cars, 51.6ms
# Speed: 1.5ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 950, 'Flow': 8, 'Density': 9, 'Speed': 9.059394946925972}
# 0: 384x640 7 cars, 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 975, 'Flow': 6, 'Density': 6, 'Speed': 2.0729522031133034}
# 0: 384x640 9 cars, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1000, 'Flow': 4, 'Density': 9, 'Speed': 3.1998406000331463}
# 0: 384x640 9 cars, 1 traffic light, 52.2ms
# Speed: 1.5ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1025, 'Flow': 7, 'Density': 8, 'Speed': 5.011827906783777}
# 0: 384x640 7 cars, 1 truck, 52.3ms
# Speed: 1.7ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1050, 'Flow': 5, 'Density': 7, 'Speed': 1.0607256790010038}
# 0: 384x640 11 cars, 1 truck, 52.9ms
# Speed: 1.6ms preprocess, 52.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1075, 'Flow': 8, 'Density': 9, 'Speed': 4.123360271921316}
# 0: 384x640 9 cars, 1 truck, 51.9ms
# Speed: 1.2ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1100, 'Flow': 8, 'Density': 8, 'Speed': 7.095166651842519}
# 0: 384x640 11 cars, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1125, 'Flow': 9, 'Density': 9, 'Speed': 1.1526505087920749}
# 0: 384x640 6 cars, 1 truck, 49.5ms
# Speed: 1.4ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1150, 'Flow': 7, 'Density': 7, 'Speed': 3.8834315753557753}
# 0: 384x640 11 cars, 52.5ms
# Speed: 1.3ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1175, 'Flow': 8, 'Density': 11, 'Speed': 0.50003088040021}
# 0: 384x640 7 cars, 52.8ms
# Speed: 1.1ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1200, 'Flow': 6, 'Density': 7, 'Speed': 5.6001829948985655}
# 0: 384x640 9 cars, 1 traffic light, 49.8ms
# Speed: 1.8ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1225, 'Flow': 8, 'Density': 8, 'Speed': 3.4918609209877225}
# 0: 384x640 10 cars, 1 bus, 1 truck, 50.5ms
# Speed: 1.4ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1250, 'Flow': 8, 'Density': 10, 'Speed': 1.2748336082798253}
# 0: 384x640 1 person, 10 cars, 2 trucks, 50.1ms
# Speed: 2.8ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1275, 'Flow': 8, 'Density': 9, 'Speed': 3.4733254994775957}
# 0: 384x640 9 cars, 1 truck, 2 traffic lights, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1300, 'Flow': 8, 'Density': 8, 'Speed': 8.125561324023584}
# 0: 384x640 7 cars, 2 trucks, 1 traffic light, 52.9ms
# Speed: 2.2ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1325, 'Flow': 7, 'Density': 8, 'Speed': 6.731871749029232}
# 0: 384x640 5 cars, 3 trucks, 1 traffic light, 51.7ms
# Speed: 2.1ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1350, 'Flow': 6, 'Density': 8, 'Speed': 0}
# 0: 384x640 10 cars, 1 truck, 1 traffic light, 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1375, 'Flow': 8, 'Density': 10, 'Speed': 0}
# 0: 384x640 8 cars, 1 truck, 1 traffic light, 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1400, 'Flow': 7, 'Density': 9, 'Speed': 0}
# 0: 384x640 11 cars, 2 trucks, 2 traffic lights, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1425, 'Flow': 10, 'Density': 12, 'Speed': 4.830235847196043}
# 0: 384x640 1 person, 12 cars, 1 bus, 3 trucks, 1 traffic light, 51.7ms
# Speed: 1.9ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1450, 'Flow': 11, 'Density': 13, 'Speed': 4.578206783438491}
# 0: 384x640 10 cars, 2 trucks, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1475, 'Flow': 9, 'Density': 10, 'Speed': 5.01332903307929}
# 0: 384x640 8 cars, 1 bus, 6 trucks, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1500, 'Flow': 10, 'Density': 14, 'Speed': 4.374874274783679}
# 0: 384x640 14 cars, 2 trucks, 52.0ms
# Speed: 1.8ms preprocess, 52.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1525, 'Flow': 12, 'Density': 15, 'Speed': 5.927721853712145}
# 0: 384x640 13 cars, 2 trucks, 1 traffic light, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1550, 'Flow': 11, 'Density': 14, 'Speed': 2.928377022559612}
# 0: 384x640 7 cars, 2 trucks, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1575, 'Flow': 6, 'Density': 8, 'Speed': 4.142990827987617}
# 0: 384x640 5 cars, 2 trucks, 1 stop sign, 48.5ms
# Speed: 1.7ms preprocess, 48.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1600, 'Flow': 4, 'Density': 7, 'Speed': 1.5195322436296474}
# 0: 384x640 13 cars, 1 truck, 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1625, 'Flow': 9, 'Density': 13, 'Speed': 5.1810887285762695}
# 0: 384x640 12 cars, 1 truck, 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1650, 'Flow': 11, 'Density': 12, 'Speed': 8.246098595734722}
# 0: 384x640 14 cars, 2 trucks, 51.9ms
# Speed: 1.6ms preprocess, 51.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1675, 'Flow': 11, 'Density': 11, 'Speed': 5.197732613452507}
# 0: 384x640 11 cars, 2 trucks, 51.0ms
# Speed: 2.6ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1700, 'Flow': 11, 'Density': 12, 'Speed': 3.7940617401083774}
# 0: 384x640 6 cars, 2 buss, 2 trucks, 51.1ms
# Speed: 1.4ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1725, 'Flow': 8, 'Density': 9, 'Speed': 3.4783895321021325}
# 0: 384x640 8 cars, 2 buss, 2 trucks, 52.1ms
# Speed: 1.3ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1750, 'Flow': 9, 'Density': 11, 'Speed': 12.19413087474083}
# 0: 384x640 12 cars, 1 bus, 1 truck, 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1775, 'Flow': 10, 'Density': 11, 'Speed': 6.3651570657359}
# 0: 384x640 12 cars, 2 trucks, 51.7ms
# Speed: 2.5ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1800, 'Flow': 9, 'Density': 11, 'Speed': 4.972874648294892}
# 0: 384x640 13 cars, 1 truck, 51.2ms
# Speed: 2.2ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1825, 'Flow': 9, 'Density': 13, 'Speed': 5.8335349614158085}
# 0: 384x640 12 cars, 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1850, 'Flow': 7, 'Density': 10, 'Speed': 5.751653577136468}
# 0: 384x640 9 cars, 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1875, 'Flow': 7, 'Density': 9, 'Speed': 3.116638218237121}
# 0: 384x640 9 cars, 2 trucks, 53.1ms
# Speed: 2.2ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1900, 'Flow': 7, 'Density': 11, 'Speed': 0}
# 0: 384x640 6 cars, 2 trucks, 53.0ms
# Speed: 1.6ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1925, 'Flow': 6, 'Density': 8, 'Speed': 0}
# 0: 384x640 12 cars, 1 truck, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1950, 'Flow': 11, 'Density': 13, 'Speed': 3.2903091873179284}
# 0: 384x640 5 cars, 1 truck, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 1975, 'Flow': 3, 'Density': 6, 'Speed': 6.543530272860347}
# 0: 384x640 4 cars, 2 trucks, 49.3ms
# Speed: 1.8ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2000, 'Flow': 3, 'Density': 5, 'Speed': 9.557293235511233}
# 0: 384x640 6 cars, 2 trucks, 1 traffic light, 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2025, 'Flow': 5, 'Density': 8, 'Speed': 0}
# 0: 384x640 9 cars, 2 trucks, 49.4ms
# Speed: 1.9ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2050, 'Flow': 7, 'Density': 10, 'Speed': 3.4839723702698984}
# 0: 384x640 8 cars, 1 truck, 52.0ms
# Speed: 1.8ms preprocess, 52.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2075, 'Flow': 7, 'Density': 8, 'Speed': 6.688428218213262}
# 0: 384x640 8 cars, 1 bus, 55.7ms
# Speed: 1.6ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2100, 'Flow': 5, 'Density': 8, 'Speed': 7.172313262329224}
# 0: 384x640 6 cars, 2 trucks, 52.9ms
# Speed: 2.7ms preprocess, 52.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2125, 'Flow': 6, 'Density': 8, 'Speed': 3.691433736880915}
# 0: 384x640 10 cars, 2 trucks, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2150, 'Flow': 9, 'Density': 10, 'Speed': 3.169967511839934}
# 0: 384x640 10 cars, 1 truck, 51.0ms
# Speed: 1.9ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2175, 'Flow': 7, 'Density': 9, 'Speed': 2.620600815572968}
# 0: 384x640 10 cars, 1 truck, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2200, 'Flow': 8, 'Density': 10, 'Speed': 3.979371359003638}
# 0: 384x640 10 cars, 3 trucks, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2225, 'Flow': 10, 'Density': 13, 'Speed': 5.3874143579894485}
# 0: 384x640 14 cars, 49.0ms
# Speed: 1.5ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2250, 'Flow': 11, 'Density': 12, 'Speed': 3.6005279069956173}
# 0: 384x640 3 cars, 2 trucks, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2275, 'Flow': 4, 'Density': 5, 'Speed': 5.0598804421504955}
# 0: 384x640 2 cars, 3 trucks, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2300, 'Flow': 3, 'Density': 4, 'Speed': 5.50033968440231}
# 0: 384x640 9 cars, 3 trucks, 52.7ms
# Speed: 2.3ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2325, 'Flow': 8, 'Density': 11, 'Speed': 3.4051917936461362}
# 0: 384x640 7 cars, 1 truck, 54.3ms
# Speed: 1.2ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2350, 'Flow': 6, 'Density': 8, 'Speed': 5.427308842263574}
# 0: 384x640 9 cars, 2 trucks, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2375, 'Flow': 8, 'Density': 8, 'Speed': 4.7452752303374295}
# 0: 384x640 8 cars, 1 truck, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2400, 'Flow': 7, 'Density': 9, 'Speed': 2.3644737052312377}
# 0: 384x640 10 cars, 2 trucks, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2425, 'Flow': 8, 'Density': 10, 'Speed': 2.2272192746491366}
# 0: 384x640 7 cars, 2 trucks, 56.2ms
# Speed: 1.7ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2450, 'Flow': 5, 'Density': 7, 'Speed': 0.750046320600315}
# 0: 384x640 5 cars, 3 trucks, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2475, 'Flow': 5, 'Density': 7, 'Speed': 3.2900163034052365}
# 0: 384x640 3 cars, 3 trucks, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2500, 'Flow': 4, 'Density': 6, 'Speed': 3.959470606908559}
# 0: 384x640 8 cars, 2 buss, 2 trucks, 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2525, 'Flow': 7, 'Density': 10, 'Speed': 7.0703799831072205}
# 0: 384x640 10 cars, 1 bus, 2 trucks, 52.1ms
# Speed: 1.9ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2550, 'Flow': 8, 'Density': 9, 'Speed': 3.897404697951317}
# 0: 384x640 11 cars, 3 trucks, 52.2ms
# Speed: 1.4ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2575, 'Flow': 10, 'Density': 12, 'Speed': 4.411137899852591}
# 0: 384x640 11 cars, 1 truck, 1 traffic light, 50.0ms
# Speed: 2.1ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2600, 'Flow': 8, 'Density': 9, 'Speed': 4.694615845385931}
# 0: 384x640 10 cars, 2 trucks, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2625, 'Flow': 8, 'Density': 9, 'Speed': 2.765229537050429}
# 0: 384x640 12 cars, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2650, 'Flow': 10, 'Density': 10, 'Speed': 3.4940526272028207}
# 0: 384x640 10 cars, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2675, 'Flow': 9, 'Density': 9, 'Speed': 5.104389791299192}
# 0: 384x640 9 cars, 2 trucks, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2700, 'Flow': 8, 'Density': 10, 'Speed': 2.512624077370843}
# 0: 384x640 8 cars, 2 trucks, 52.7ms
# Speed: 1.8ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2725, 'Flow': 8, 'Density': 9, 'Speed': 1.50009264120063}
# 0: 384x640 14 cars, 1 truck, 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2750, 'Flow': 10, 'Density': 15, 'Speed': 5.08416345332078}
# 0: 384x640 12 cars, 1 truck, 53.3ms
# Speed: 2.5ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2775, 'Flow': 9, 'Density': 11, 'Speed': 5.194405679101011}
# 0: 384x640 10 cars, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2800, 'Flow': 8, 'Density': 9, 'Speed': 4.886302637288434}
# 0: 384x640 9 cars, 1 truck, 51.1ms
# Speed: 1.9ms preprocess, 51.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2825, 'Flow': 8, 'Density': 8, 'Speed': 5.847010737313117}
# 0: 384x640 8 cars, 1 bus, 1 truck, 51.1ms
# Speed: 2.3ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2850, 'Flow': 7, 'Density': 8, 'Speed': 0}
# 0: 384x640 8 cars, 1 bus, 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2875, 'Flow': 6, 'Density': 7, 'Speed': 3.8245008248394763}
# 0: 384x640 10 cars, 4 trucks, 54.0ms
# Speed: 1.9ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2900, 'Flow': 11, 'Density': 12, 'Speed': 7.197018265955932}
# 0: 384x640 6 cars, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2925, 'Flow': 4, 'Density': 4, 'Speed': 12.563120386854214}
# 0: 384x640 8 cars, 52.2ms
# Speed: 2.5ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2950, 'Flow': 7, 'Density': 8, 'Speed': 1.8201398786736065}
# 0: 384x640 11 cars, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 2975, 'Flow': 7, 'Density': 10, 'Speed': 3.144031652016744}
# 0: 384x640 6 cars, 1 truck, 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3000, 'Flow': 5, 'Density': 7, 'Speed': 8.004399624388677}
# 0: 384x640 11 cars, 1 truck, 50.0ms
# Speed: 2.7ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3025, 'Flow': 10, 'Density': 10, 'Speed': 2.5496672165596506}
# 0: 384x640 13 cars, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3050, 'Flow': 11, 'Density': 12, 'Speed': 6.337033430480177}
# 0: 384x640 10 cars, 50.4ms
# Speed: 1.9ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3075, 'Flow': 8, 'Density': 8, 'Speed': 3.8059890966581458}
# 0: 384x640 10 cars, 1 truck, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3100, 'Flow': 8, 'Density': 9, 'Speed': 1.250077201000525}
# 0: 384x640 12 cars, 1 truck, 49.1ms
# Speed: 1.6ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3125, 'Flow': 9, 'Density': 10, 'Speed': 6.091814915586954}
# 0: 384x640 12 cars, 1 truck, 53.2ms
# Speed: 1.7ms preprocess, 53.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3150, 'Flow': 9, 'Density': 11, 'Speed': 6.062766741075959}
# 0: 384x640 8 cars, 1 truck, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3175, 'Flow': 7, 'Density': 9, 'Speed': 4.826622640426001}
# 0: 384x640 13 cars, 51.7ms
# Speed: 2.2ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3200, 'Flow': 9, 'Density': 9, 'Speed': 2.469303871178819}
# 0: 384x640 11 cars, 1 truck, 51.7ms
# Speed: 2.2ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3225, 'Flow': 11, 'Density': 12, 'Speed': 6.174898581706685}
# 0: 384x640 14 cars, 1 truck, 52.9ms
# Speed: 2.4ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3250, 'Flow': 8, 'Density': 10, 'Speed': 3.25072142000368}
# 0: 384x640 10 cars, 1 bus, 2 traffic lights, 52.7ms
# Speed: 1.4ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3275, 'Flow': 7, 'Density': 9, 'Speed': 5.237917187014982}
# 0: 384x640 13 cars, 1 bus, 1 truck, 51.6ms
# Speed: 2.6ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3300, 'Flow': 10, 'Density': 13, 'Speed': 3.513401736583201}
# 0: 384x640 10 cars, 1 truck, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3325, 'Flow': 9, 'Density': 10, 'Speed': 2.215953045461255}
# 0: 384x640 11 cars, 1 truck, 52.2ms
# Speed: 1.5ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3350, 'Flow': 8, 'Density': 12, 'Speed': 5.579878409191444}
# 0: 384x640 12 cars, 1 truck, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3375, 'Flow': 11, 'Density': 13, 'Speed': 4.31593566458755}
# 0: 384x640 17 cars, 1 truck, 1 traffic light, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3400, 'Flow': 13, 'Density': 16, 'Speed': 2.327008201178654}
# 0: 384x640 10 cars, 1 truck, 50.2ms
# Speed: 1.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3425, 'Flow': 8, 'Density': 9, 'Speed': 2.9857108840144897}
# 0: 384x640 14 cars, 2 trucks, 1 traffic light, 52.9ms
# Speed: 3.2ms preprocess, 52.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3450, 'Flow': 12, 'Density': 15, 'Speed': 7.190779331309296}
# 0: 384x640 10 cars, 1 truck, 50.8ms
# Speed: 3.0ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3475, 'Flow': 9, 'Density': 10, 'Speed': 3.6814604524261214}
# 0: 384x640 10 cars, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3500, 'Flow': 8, 'Density': 9, 'Speed': 2.6000715379522386}
# 0: 384x640 10 cars, 52.2ms
# Speed: 1.4ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3525, 'Flow': 8, 'Density': 10, 'Speed': 2.9875893213290072}
# 0: 384x640 9 cars, 2 trucks, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3550, 'Flow': 9, 'Density': 10, 'Speed': 5.763464368748901}
# 0: 384x640 9 cars, 2 trucks, 1 traffic light, 54.4ms
# Speed: 1.9ms preprocess, 54.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3575, 'Flow': 10, 'Density': 11, 'Speed': 16.758597187494445}
# 0: 384x640 8 cars, 3 trucks, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3600, 'Flow': 7, 'Density': 8, 'Speed': 5.047085355211932}
# 0: 384x640 9 cars, 1 truck, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3625, 'Flow': 9, 'Density': 9, 'Speed': 3.7167467219058596}
# 0: 384x640 5 cars, 3 trucks, 50.4ms
# Speed: 1.7ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3650, 'Flow': 2, 'Density': 6, 'Speed': 0}
# 0: 384x640 7 cars, 1 bus, 2 trucks, 50.2ms
# Speed: 2.5ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3675, 'Flow': 6, 'Density': 8, 'Speed': 0}
# 0: 384x640 8 cars, 4 trucks, 52.1ms
# Speed: 3.4ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3700, 'Flow': 8, 'Density': 11, 'Speed': 5.602572142018696}
# 0: 384x640 12 cars, 1 truck, 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3725, 'Flow': 8, 'Density': 10, 'Speed': 2.569454648197755}
# 0: 384x640 11 cars, 1 truck, 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3750, 'Flow': 9, 'Density': 11, 'Speed': 4.3272380180579075}
# 0: 384x640 9 cars, 51.5ms
# Speed: 2.8ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3775, 'Flow': 9, 'Density': 9, 'Speed': 3.573041290748182}
# 0: 384x640 11 cars, 1 truck, 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3800, 'Flow': 10, 'Density': 10, 'Speed': 1.1957490830598454}
# 0: 384x640 1 person, 6 cars, 3 trucks, 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3825, 'Flow': 8, 'Density': 9, 'Speed': 5.37884219654597}
# 0: 384x640 2 cars, 4 trucks, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3850, 'Flow': 3, 'Density': 6, 'Speed': 6.731871749029232}
# 0: 384x640 6 cars, 3 trucks, 49.9ms
# Speed: 2.2ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3875, 'Flow': 8, 'Density': 9, 'Speed': 0}
# 0: 384x640 9 cars, 4 trucks, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3900, 'Flow': 8, 'Density': 12, 'Speed': 6.770386220641024}
# 0: 384x640 6 cars, 2 trucks, 54.5ms
# Speed: 1.5ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3925, 'Flow': 6, 'Density': 7, 'Speed': 3.010584569327954}
# 0: 384x640 4 cars, 4 trucks, 51.8ms
# Speed: 1.8ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3950, 'Flow': 6, 'Density': 8, 'Speed': 0}
# 0: 384x640 1 car, 5 trucks, 51.6ms
# Speed: 2.5ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 3975, 'Flow': 2, 'Density': 4, 'Speed': 3.1821770370030116}
# 0: 384x640 10 cars, 2 trucks, 53.4ms
# Speed: 1.7ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4000, 'Flow': 8, 'Density': 10, 'Speed': 9.424620448640926}
# 0: 384x640 10 cars, 1 bus, 1 truck, 49.6ms
# Speed: 2.3ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4025, 'Flow': 8, 'Density': 10, 'Speed': 3.2812597321267627}
# 0: 384x640 11 cars, 1 truck, 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4050, 'Flow': 10, 'Density': 12, 'Speed': 5.888116403235888}
# 0: 384x640 11 cars, 1 truck, 51.8ms
# Speed: 2.3ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4075, 'Flow': 9, 'Density': 11, 'Speed': 4.512834261269167}
# 0: 384x640 9 cars, 2 trucks, 51.5ms
# Speed: 1.9ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4100, 'Flow': 8, 'Density': 10, 'Speed': 3.3827048154484216}
# 0: 384x640 14 cars, 1 truck, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4125, 'Flow': 12, 'Density': 14, 'Speed': 2.826985322676249}
# 0: 384x640 12 cars, 1 truck, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4150, 'Flow': 11, 'Density': 12, 'Speed': 4.354119887729169}
# 0: 384x640 8 cars, 1 truck, 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4175, 'Flow': 6, 'Density': 7, 'Speed': 2.9603489917491617}
# 0: 384x640 1 car, 2 trucks, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4200, 'Flow': 3, 'Density': 3, 'Speed': 8.601312250480674}
# 0: 384x640 7 cars, 2 trucks, 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4225, 'Flow': 8, 'Density': 9, 'Speed': 0}
# 0: 384x640 10 cars, 1 truck, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4250, 'Flow': 8, 'Density': 10, 'Speed': 3.5119615081069298}
# 0: 384x640 12 cars, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4275, 'Flow': 11, 'Density': 11, 'Speed': 4.203125769639601}
# 0: 384x640 14 cars, 48.2ms
# Speed: 1.8ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4300, 'Flow': 10, 'Density': 11, 'Speed': 6.114478257324522}
# 0: 384x640 12 cars, 1 truck, 52.4ms
# Speed: 2.1ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4325, 'Flow': 11, 'Density': 13, 'Speed': 4.673194364393142}
# 0: 384x640 9 cars, 1 truck, 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4350, 'Flow': 9, 'Density': 9, 'Speed': 2.718542114827263}
# 0: 384x640 13 cars, 1 truck, 50.2ms
# Speed: 1.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4375, 'Flow': 11, 'Density': 11, 'Speed': 3.7249677188292467}
# 0: 384x640 10 cars, 49.5ms
# Speed: 2.4ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4400, 'Flow': 8, 'Density': 9, 'Speed': 2.8654929070421784}
# 0: 384x640 12 cars, 49.4ms
# Speed: 1.7ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4425, 'Flow': 9, 'Density': 9, 'Speed': 5.203990753527647}
# 0: 384x640 13 cars, 51.9ms
# Speed: 1.7ms preprocess, 51.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4450, 'Flow': 9, 'Density': 11, 'Speed': 6.557002545632683}
# 0: 384x640 13 cars, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4475, 'Flow': 9, 'Density': 9, 'Speed': 6.822074944334126}
# 0: 384x640 10 cars, 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4500, 'Flow': 7, 'Density': 7, 'Speed': 5.197645550551234}
# 0: 384x640 11 cars, 52.5ms
# Speed: 2.2ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4525, 'Flow': 9, 'Density': 10, 'Speed': 6.124850631586782}
# 0: 384x640 14 cars, 54.8ms
# Speed: 1.6ms preprocess, 54.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4550, 'Flow': 12, 'Density': 13, 'Speed': 7.1234917605539065}
# 0: 384x640 11 cars, 49.8ms
# Speed: 2.3ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4575, 'Flow': 10, 'Density': 11, 'Speed': 5.640991526093554}
# 0: 384x640 12 cars, 1 traffic light, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4600, 'Flow': 10, 'Density': 12, 'Speed': 3.6240754247086997}
# 0: 384x640 15 cars, 53.0ms
# Speed: 2.5ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4625, 'Flow': 11, 'Density': 13, 'Speed': 3.9435706765623784}
# 0: 384x640 13 cars, 1 traffic light, 50.7ms
# Speed: 2.1ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4650, 'Flow': 10, 'Density': 12, 'Speed': 5.877549375872147}
# 0: 384x640 11 cars, 51.4ms
# Speed: 2.6ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4675, 'Flow': 8, 'Density': 9, 'Speed': 4.677677697486237}
# 0: 384x640 11 cars, 52.8ms
# Speed: 2.2ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4700, 'Flow': 9, 'Density': 11, 'Speed': 3.3583675183025323}
# 0: 384x640 7 cars, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4725, 'Flow': 6, 'Density': 7, 'Speed': 2.136132857456908}
# 0: 384x640 9 cars, 51.7ms
# Speed: 1.9ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4750, 'Flow': 6, 'Density': 8, 'Speed': 2.6531057240874816}
# 0: 384x640 7 cars, 2 trucks, 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4775, 'Flow': 8, 'Density': 8, 'Speed': 6.750416885402835}
# 0: 384x640 10 cars, 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4800, 'Flow': 9, 'Density': 9, 'Speed': 3.805121107135149}
# 0: 384x640 1 person, 7 cars, 52.4ms
# Speed: 1.9ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4825, 'Flow': 6, 'Density': 7, 'Speed': 0}
# 0: 384x640 9 cars, 1 bus, 1 truck, 52.4ms
# Speed: 1.8ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4850, 'Flow': 9, 'Density': 9, 'Speed': 5.722764199326036}
# 0: 384x640 7 cars, 50.8ms
# Speed: 2.1ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4875, 'Flow': 6, 'Density': 6, 'Speed': 4.38989735144069}
# 0: 384x640 10 cars, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4900, 'Flow': 8, 'Density': 10, 'Speed': 5.0624268230528955}
# 0: 384x640 11 cars, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4925, 'Flow': 5, 'Density': 9, 'Speed': 2.1242450428214217}
# 0: 384x640 5 cars, 51.8ms
# Speed: 3.3ms preprocess, 51.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4950, 'Flow': 4, 'Density': 5, 'Speed': 3.663206462272905}
# 0: 384x640 9 cars, 55.4ms
# Speed: 1.3ms preprocess, 55.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 4975, 'Flow': 7, 'Density': 9, 'Speed': 3.7628564707099033}
# 0: 384x640 1 person, 8 cars, 48.7ms
# Speed: 2.3ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5000, 'Flow': 6, 'Density': 8, 'Speed': 4.562353654935642}
# 0: 384x640 2 cars, 2 trucks, 53.6ms
# Speed: 2.6ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5025, 'Flow': 1, 'Density': 3, 'Speed': 0}
# 0: 384x640 5 cars, 2 trucks, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5050, 'Flow': 5, 'Density': 7, 'Speed': 0}
# 0: 384x640 11 cars, 51.7ms
# Speed: 2.4ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5075, 'Flow': 8, 'Density': 10, 'Speed': 1.3463743498058465}
# 0: 384x640 8 cars, 1 truck, 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5100, 'Flow': 7, 'Density': 9, 'Speed': 3.5148724140053353}
# 0: 384x640 7 cars, 1 truck, 50.6ms
# Speed: 1.7ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5125, 'Flow': 6, 'Density': 8, 'Speed': 5.363195039141658}
# 0: 384x640 6 cars, 53.6ms
# Speed: 1.8ms preprocess, 53.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5150, 'Flow': 4, 'Density': 6, 'Speed': 6.0254856602830955}
# 0: 384x640 6 cars, 1 bus, 1 truck, 51.0ms
# Speed: 2.7ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5175, 'Flow': 5, 'Density': 8, 'Speed': 3.162472964967822}
# 0: 384x640 9 cars, 2 trucks, 52.6ms
# Speed: 1.8ms preprocess, 52.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5200, 'Flow': 7, 'Density': 9, 'Speed': 7.7339046068147335}
# 0: 384x640 8 cars, 1 truck, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5225, 'Flow': 6, 'Density': 9, 'Speed': 2.2500960901703944}
# 0: 384x640 11 cars, 2 trucks, 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5250, 'Flow': 6, 'Density': 10, 'Speed': 4.347486400192615}
# 0: 384x640 9 cars, 1 truck, 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5275, 'Flow': 6, 'Density': 8, 'Speed': 1.029572080456299}
# 0: 384x640 6 cars, 1 truck, 53.0ms
# Speed: 2.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5300, 'Flow': 4, 'Density': 5, 'Speed': 3.444330881150755}
# 0: 384x640 3 cars, 1 truck, 50.8ms
# Speed: 1.9ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5325, 'Flow': 2, 'Density': 3, 'Speed': 4.100558104824716}
# 0: 384x640 5 cars, 1 truck, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5350, 'Flow': 5, 'Density': 6, 'Speed': 3.5533870473630307}
# 0: 384x640 8 cars, 1 truck, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5375, 'Flow': 7, 'Density': 9, 'Speed': 1.904060865526686}
# 0: 384x640 10 cars, 2 trucks, 51.9ms
# Speed: 2.6ms preprocess, 51.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5400, 'Flow': 9, 'Density': 11, 'Speed': 6.191714447236426}
# 0: 384x640 7 cars, 1 bus, 2 trucks, 52.1ms
# Speed: 2.8ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5425, 'Flow': 5, 'Density': 9, 'Speed': 4.092118359518351}
# 0: 384x640 11 cars, 3 buss, 52.4ms
# Speed: 1.9ms preprocess, 52.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5450, 'Flow': 7, 'Density': 11, 'Speed': 5.546922499314036}
# 0: 384x640 9 cars, 2 buss, 1 truck, 52.8ms
# Speed: 1.1ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5475, 'Flow': 9, 'Density': 12, 'Speed': 4.700559197205366}
# 0: 384x640 13 cars, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5500, 'Flow': 10, 'Density': 10, 'Speed': 6.000809774295224}
# 0: 384x640 12 cars, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5525, 'Flow': 10, 'Density': 10, 'Speed': 4.402904446527762}
# 0: 384x640 10 cars, 1 truck, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5550, 'Flow': 9, 'Density': 11, 'Speed': 3.100972566078365}
# 0: 384x640 2 cars, 3 trucks, 51.2ms
# Speed: 2.7ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5575, 'Flow': 1, 'Density': 5, 'Speed': 0}
# 0: 384x640 6 cars, 1 truck, 50.8ms
# Speed: 2.7ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5600, 'Flow': 5, 'Density': 5, 'Speed': 0}
# 0: 384x640 13 cars, 1 truck, 53.7ms
# Speed: 2.1ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5625, 'Flow': 10, 'Density': 11, 'Speed': 0}
# 0: 384x640 8 cars, 1 truck, 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5650, 'Flow': 6, 'Density': 8, 'Speed': 3.0647646453869974}
# 0: 384x640 8 cars, 1 truck, 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5675, 'Flow': 7, 'Density': 7, 'Speed': 11.102487311743612}
# 0: 384x640 7 cars, 1 truck, 51.9ms
# Speed: 1.7ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5700, 'Flow': 6, 'Density': 7, 'Speed': 3.691433736880915}
# 0: 384x640 7 cars, 1 truck, 51.7ms
# Speed: 3.0ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5725, 'Flow': 5, 'Density': 7, 'Speed': 5.221324968248364}
# 0: 384x640 11 cars, 2 trucks, 51.1ms
# Speed: 2.2ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5750, 'Flow': 9, 'Density': 10, 'Speed': 4.200051778943307}
# 0: 384x640 11 cars, 1 truck, 53.1ms
# Speed: 1.8ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5775, 'Flow': 10, 'Density': 11, 'Speed': 4.496456837147412}
# 0: 384x640 8 cars, 1 traffic light, 54.7ms
# Speed: 2.3ms preprocess, 54.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5800, 'Flow': 7, 'Density': 7, 'Speed': 3.911091039390704}
# 0: 384x640 11 cars, 1 truck, 1 traffic light, 52.5ms
# Speed: 1.6ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5825, 'Flow': 8, 'Density': 8, 'Speed': 0.9340746800121259}
# 0: 384x640 14 cars, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5850, 'Flow': 9, 'Density': 11, 'Speed': 9.03175370798386}
# 0: 384x640 7 cars, 1 bus, 1 traffic light, 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5875, 'Flow': 6, 'Density': 8, 'Speed': 0.750046320600315}
# 0: 384x640 8 cars, 1 bus, 1 truck, 1 traffic light, 51.6ms
# Speed: 2.3ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5900, 'Flow': 6, 'Density': 9, 'Speed': 4.596477942337684}
# 0: 384x640 9 cars, 1 truck, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 5925, 'Flow': 6, 'Density': 10, 'Speed': 3.252784132446221}
# 0: 384x640 11 cars, 1 truck, 1 traffic light, 60.7ms
# ...
# {'Frame': 52650, 'Flow': 7, 'Density': 7, 'Speed': 0}
# 0: 384x640 2 cars, 1 truck, 52.3ms
# Speed: 1.6ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52675, 'Flow': 3, 'Density': 3, 'Speed': 0}
# 0: 384x640 4 cars, 1 traffic light, 52.5ms
# Speed: 1.8ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52700, 'Flow': 4, 'Density': 4, 'Speed': 6.129695741675444}
# 0: 384x640 6 cars, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52725, 'Flow': 5, 'Density': 5, 'Speed': 0}
# 0: 384x640 2 cars, 1 truck, 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52750, 'Flow': 2, 'Density': 3, 'Speed': 0}
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 71.0ms
# Speed: 1.6ms preprocess, 71.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52775, 'Flow': 4, 'Density': 5, 'Speed': 0}
# 0: 384x640 2 cars, 1 truck, 2 traffic lights, 94.1ms
# Speed: 4.0ms preprocess, 94.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52800, 'Flow': 2, 'Density': 3, 'Speed': 0}
# 0: 384x640 3 cars, 1 traffic light, 63.8ms
# Speed: 3.3ms preprocess, 63.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52825, 'Flow': 3, 'Density': 3, 'Speed': 1.360674655149279}
# 0: 384x640 2 cars, 67.7ms
# Speed: 1.5ms preprocess, 67.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52850, 'Flow': 2, 'Density': 2, 'Speed': 0}
# 0: 384x640 1 car, 1 traffic light, 58.8ms
# Speed: 2.3ms preprocess, 58.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52875, 'Flow': 1, 'Density': 1, 'Speed': 0}
# 0: 384x640 6 cars, 2 trucks, 1 traffic light, 57.0ms
# Speed: 1.5ms preprocess, 57.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52900, 'Flow': 7, 'Density': 8, 'Speed': 0}
# 0: 384x640 9 cars, 1 traffic light, 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52925, 'Flow': 8, 'Density': 8, 'Speed': 5.018469942572337}
# 0: 384x640 4 cars, 1 traffic light, 53.2ms
# Speed: 1.8ms preprocess, 53.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52950, 'Flow': 4, 'Density': 4, 'Speed': 1.650060389788636}
# 0: 384x640 6 cars, 1 traffic light, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 52975, 'Flow': 6, 'Density': 6, 'Speed': 0}
# 0: 384x640 5 cars, 1 traffic light, 54.0ms
# Speed: 1.7ms preprocess, 54.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53000, 'Flow': 5, 'Density': 5, 'Speed': 3.1133277168039903}
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 57.2ms
# Speed: 1.9ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53025, 'Flow': 2, 'Density': 2, 'Speed': 1.193994914749037}
# 0: 384x640 2 cars, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53050, 'Flow': 2, 'Density': 2, 'Speed': 0}
# 0: 384x640 1 car, 53.6ms
# Speed: 1.7ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53075, 'Flow': 1, 'Density': 1, 'Speed': 1.4758588794188758}
# 0: 384x640 1 car, 55.4ms
# Speed: 1.9ms preprocess, 55.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53100, 'Flow': 1, 'Density': 1, 'Speed': 0}
# 0: 384x640 (no detections), 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53125, 'Flow': 0, 'Density': 0, 'Speed': 0}
# 0: 384x640 3 cars, 53.2ms
# Speed: 1.7ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53150, 'Flow': 3, 'Density': 3, 'Speed': 0}
# 0: 384x640 3 cars, 55.7ms
# Speed: 1.6ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53175, 'Flow': 3, 'Density': 3, 'Speed': 0.33001207795772713}
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.4ms preprocess, 56.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53200, 'Flow': 0, 'Density': 0, 'Speed': 0}
# 0: 384x640 4 cars, 1 traffic light, 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53225, 'Flow': 4, 'Density': 4, 'Speed': 0}
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 58.0ms
# Speed: 2.1ms preprocess, 58.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53250, 'Flow': 3, 'Density': 3, 'Speed': 0}
# 0: 384x640 1 car, 2 trucks, 56.6ms
# Speed: 1.0ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53275, 'Flow': 1, 'Density': 3, 'Speed': 0}
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 56.4ms
# Speed: 1.3ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53300, 'Flow': 4, 'Density': 4, 'Speed': 0}
# 0: 384x640 5 cars, 1 truck, 1 traffic light, 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53325, 'Flow': 6, 'Density': 6, 'Speed': 0}
# 0: 384x640 3 cars, 2 traffic lights, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53350, 'Flow': 3, 'Density': 3, 'Speed': 0}
# 0: 384x640 7 cars, 54.2ms
# Speed: 1.7ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53375, 'Flow': 7, 'Density': 7, 'Speed': 3.6301328575349987}
# 0: 384x640 10 cars, 1 motorcycle, 1 truck, 1 traffic light, 54.5ms
# Speed: 2.1ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53400, 'Flow': 9, 'Density': 9, 'Speed': 6.77119614283933}
# 0: 384x640 7 cars, 2 trucks, 1 traffic light, 53.6ms
# Speed: 1.8ms preprocess, 53.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53425, 'Flow': 8, 'Density': 8, 'Speed': 4.533440508107228}
# 0: 384x640 9 cars, 1 truck, 1 traffic light, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53450, 'Flow': 10, 'Density': 10, 'Speed': 9.36953752864202}
# 0: 384x640 10 cars, 1 truck, 1 traffic light, 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53475, 'Flow': 10, 'Density': 11, 'Speed': 4.40438572319817}
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53500, 'Flow': 4, 'Density': 5, 'Speed': 2.640096623661817}
# 0: 384x640 4 cars, 3 trucks, 1 traffic light, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53525, 'Flow': 5, 'Density': 7, 'Speed': 1.4758588794188758}
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53550, 'Flow': 3, 'Density': 3, 'Speed': 2.2492593692229192}
# 0: 384x640 4 cars, 4 trucks, 1 traffic light, 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53575, 'Flow': 6, 'Density': 7, 'Speed': 3.5696264057970137}
# 0: 384x640 2 cars, 1 train, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53600, 'Flow': 2, 'Density': 2, 'Speed': 0}
# 0: 384x640 6 cars, 2 trucks, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53625, 'Flow': 4, 'Density': 6, 'Speed': 12.012620961610313}
# 0: 384x640 6 cars, 1 truck, 55.9ms
# Speed: 1.6ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53650, 'Flow': 6, 'Density': 7, 'Speed': 2.0871796434229326}
# 0: 384x640 6 cars, 3 trucks, 1 traffic light, 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53675, 'Flow': 8, 'Density': 9, 'Speed': 2.838871236644997}
# 0: 384x640 7 cars, 3 trucks, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53700, 'Flow': 9, 'Density': 10, 'Speed': 0}
# 0: 384x640 6 cars, 1 traffic light, 51.4ms
# Speed: 2.5ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53725, 'Flow': 5, 'Density': 5, 'Speed': 0}
# 0: 384x640 4 cars, 2 traffic lights, 54.0ms
# Speed: 1.9ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53750, 'Flow': 4, 'Density': 4, 'Speed': 0}
# 0: 384x640 1 train, 57.7ms
# Speed: 1.8ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53775, 'Flow': 0, 'Density': 0, 'Speed': 0}
# 0: 384x640 3 cars, 1 bus, 1 truck, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53800, 'Flow': 3, 'Density': 3, 'Speed': 0}
# 0: 384x640 3 cars, 4 trucks, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53825, 'Flow': 3, 'Density': 7, 'Speed': 0}
# 0: 384x640 10 cars, 2 trucks, 1 traffic light, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53850, 'Flow': 10, 'Density': 11, 'Speed': 4.488649545868528}
# 0: 384x640 11 cars, 3 trucks, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53875, 'Flow': 12, 'Density': 12, 'Speed': 4.036759488177371}
# 0: 384x640 9 cars, 1 truck, 2 traffic lights, 53.8ms
# Speed: 1.9ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53900, 'Flow': 7, 'Density': 8, 'Speed': 2.1131083350167015}
# 0: 384x640 9 cars, 1 traffic light, 52.4ms
# Speed: 1.8ms preprocess, 52.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53925, 'Flow': 7, 'Density': 8, 'Speed': 3.4434295512900968}
# 0: 384x640 6 cars, 1 bus, 1 truck, 1 traffic light, 56.5ms
# Speed: 1.4ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53950, 'Flow': 7, 'Density': 8, 'Speed': 4.905982238365006}
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 53975, 'Flow': 3, 'Density': 3, 'Speed': 2.402524192322063}
# 0: 384x640 5 cars, 4 trucks, 1 traffic light, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54000, 'Flow': 5, 'Density': 5, 'Speed': 5.61990318096436}
# 0: 384x640 6 cars, 1 truck, 1 traffic light, 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54025, 'Flow': 6, 'Density': 6, 'Speed': 7.73243017474386}
# 0: 384x640 6 cars, 1 truck, 1 traffic light, 66.6ms
# Speed: 1.4ms preprocess, 66.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54050, 'Flow': 7, 'Density': 7, 'Speed': 2.333537781973724}
# 0: 384x640 8 cars, 1 traffic light, 67.0ms
# Speed: 2.1ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54075, 'Flow': 7, 'Density': 7, 'Speed': 14.685905690169559}
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 56.1ms
# Speed: 1.6ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54100, 'Flow': 5, 'Density': 5, 'Speed': 0}
# 0: 384x640 6 cars, 1 traffic light, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54125, 'Flow': 6, 'Density': 6, 'Speed': 2.838871236644997}
# 0: 384x640 1 car, 58.8ms
# Speed: 1.8ms preprocess, 58.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54150, 'Flow': 1, 'Density': 1, 'Speed': 0}
# 0: 384x640 4 cars, 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54175, 'Flow': 4, 'Density': 4, 'Speed': 0}
# 0: 384x640 2 cars, 1 truck, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54200, 'Flow': 2, 'Density': 3, 'Speed': 0}
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54225, 'Flow': 2, 'Density': 2, 'Speed': 0}
# 0: 384x640 4 cars, 1 bus, 1 truck, 1 traffic light, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54250, 'Flow': 4, 'Density': 5, 'Speed': 0}
# 0: 384x640 7 cars, 3 trucks, 1 traffic light, 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54275, 'Flow': 4, 'Density': 6, 'Speed': 9.169348617739333}
# 0: 384x640 4 cars, 1 truck, 55.7ms
# Speed: 1.3ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54300, 'Flow': 5, 'Density': 5, 'Speed': 0}
# 0: 384x640 8 cars, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54325, 'Flow': 7, 'Density': 7, 'Speed': 3.5201288315490893}
# 0: 384x640 4 cars, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54350, 'Flow': 3, 'Density': 3, 'Speed': 5.123165150091538}
# 0: 384x640 3 cars, 1 traffic light, 58.9ms
# Speed: 2.1ms preprocess, 58.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54375, 'Flow': 3, 'Density': 3, 'Speed': 0}
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54400, 'Flow': 3, 'Density': 3, 'Speed': 1.682738025227754}
# 0: 384x640 6 cars, 1 traffic light, 56.2ms
# Speed: 1.8ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54425, 'Flow': 6, 'Density': 6, 'Speed': 0}
# 0: 384x640 2 cars, 1 traffic light, 54.5ms
# Speed: 1.5ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54450, 'Flow': 2, 'Density': 2, 'Speed': 0}
# 0: 384x640 3 cars, 2 trucks, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54475, 'Flow': 5, 'Density': 5, 'Speed': 0}
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.6ms preprocess, 57.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54500, 'Flow': 0, 'Density': 0, 'Speed': 0}
# 0: 384x640 (no detections), 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54525, 'Flow': 0, 'Density': 0, 'Speed': 0}
# 0: 384x640 1 car, 1 train, 55.1ms
# Speed: 1.3ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54550, 'Flow': 0, 'Density': 0, 'Speed': 0}
# 0: 384x640 8 cars, 1 truck, 1 traffic light, 67.4ms
# Speed: 2.1ms preprocess, 67.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54575, 'Flow': 8, 'Density': 8, 'Speed': 0}
# 0: 384x640 4 cars, 1 truck, 2 traffic lights, 65.0ms
# Speed: 1.6ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54600, 'Flow': 4, 'Density': 5, 'Speed': 0}
# 0: 384x640 4 cars, 3 trucks, 74.7ms
# Speed: 2.5ms preprocess, 74.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {'Frame': 54625, 'Flow': 5, 'Density': 7, 'Speed': 0}
# 100%|██████████| 4/4 [10:00<00:00, 150.04s/it]
