# %%
from tools.combine_4 import combine_four_images_with_pyplot

# %%
combine_four_images_with_pyplot(
    "./plots/q1_plots_single/107_20240501_20240501114103_20240501135755_114103_time_series.png",
    "./plots/q1_plots_single/105_20240501_20240501115227_20240501130415_115227_time_series.png",
    "./plots/q1_plots_single/108_20240501_20240501113543_20240501135236_113542_time_series.png",
    "./plots/q1_plots_single/103_20240501_20240501125647_20240501140806_125649_time_series.png",
    "Monitoring Point 1 (32.31.250.107)",
    "Monitoring Point 2 (32.31.250.105)",
    "Monitoring Point 3 (32.31.250.108)",
    "Monitoring Point 4 (32.31.250.103)")
